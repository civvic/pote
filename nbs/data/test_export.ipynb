# %% [markdown]
# #| export
# ##### Header (exported)

# %% [markdown]
# ##### Header w/ paragraph (exported)
#
# Paragraph.
# Line 2.

# %% [markdown]
# ##### Note with code fence (exported, only header)
#
# ```python
# x = 1
# ```
#
# More text.

# %% [markdown]
# Note w/out header (not exported)

# %%
#| export
# exported code
a = 13; print(a+1)
# Out:
# 14

# %%
#| export
#| echo: true
# exported code, echo
test_eq(a, 13)

# %%
# not exported
test_ne(a, 17)

# %%
# not exported
b = 42; print(b)
# Out:
# 42

# %%
#| exporti
# exported, directive
c = 99

# %%
#| hide
# not exported, hidden from docs
c = 100

# %% [markdown]
# a prompt
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# a response

# %% [markdown]
# #| export
# a prompt (exported)
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# a response

# %% [raw]
# #| export
# RAW (exported)

# %% [raw]
# RAW (not exported)

# %% [raw]
# #| export
# #| exports
# EXPORTED RAW CONTENT
# <!-- linkedto: _fake123 -->
