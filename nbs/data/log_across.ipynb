# %%
from pathlib import Path
from nbdev.config import get_config
from dutil.logger import Logger

# %%
nbs = f"/{(get_config().config_path/'nbs').relative_to(Path.home())}"
nbs
# Out:
# '/vic/dutil/nbs'

# %%
tgtid = (await find_msgs('# across target', msg_type='code', limit=1, dname=nbs+'/01_logger'))[0].id
tgtid
# Out:
# '_bae17912'

# %%
log = Logger(tgtid, nbs+'/01_logger')
# Out:
# [11:20:08.727] Some msg -> 43
# [11:20:30.822] En
# [11:20:30.861] algún
# [11:20:30.898] lugar
# [11:20:30.942] de
# [11:20:30.978] la
# [11:20:31.015] Mancha

# %%
log('asd')

# %%
log.show()
# Out:
# [11:23:38.092] asd
# [11:20:08.727] Some msg -> 43
# [11:20:30.822] En
# [11:20:30.861] algún
# [11:20:30.898] lugar
# [11:20:30.942] de
# [11:20:30.978] la
# [11:20:31.015] Mancha
